# %%
import pandas as pd

# %%
df = pd.read_csv ("dataset/babies.csv")
df
# Out:
#       case  bwt  gestation  parity   age  height  weight  smoke
# 0        1  120      284.0       0  27.0    62.0   100.0    0.0
# 1        2  113      282.0       0  33.0    64.0   135.0    0.0
# 2        3  128      279.0       0  28.0    64.0   115.0    1.0
# 3        4  123        NaN       0  36.0    69.0   190.0    0.0
# 4        5  108      282.0       0  23.0    67.0   125.0    1.0
# ...    ...  ...        ...     ...   ...     ...     ...    ...
# 1231  1232  113      275.0       1  27.0    60.0   100.0    0.0
# 1232  1233  128      265.0       0  24.0    67.0   120.0    0.0
# 1233  1234  130      291.0       0  30.0    65.0   150.0    1.0
# 1234  1235  125      281.0       1  21.0    65.0   110.0    0.0
# 1235  1236  117      297.0       0  38.0    65.0   129.0    0.0
#
# [1236 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   case       1236 non-null   int64
#  1   bwt        1236 non-null   int64
#  2   gestation  1223 non-null   float64
#  3   parity     1236 non-null   int64
#  4   age        1234 non-null   float64
#  5   height     1214 non-null   float64
#  6   weight     1200 non-null   float64
#  7   smoke      1226 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 77.4 KB

# %%
df.describe()
# Out:
#               case          bwt    gestation       parity          age  \
# count  1236.000000  1236.000000  1223.000000  1236.000000  1234.000000
# mean    618.500000   119.576861   279.338512     0.254854    27.255267
# std     356.946775    18.236452    16.027693     0.435956     5.781405
# min       1.000000    55.000000   148.000000     0.000000    15.000000
# 25%     309.750000   108.750000   272.000000     0.000000    23.000000
# 50%     618.500000   120.000000   280.000000     0.000000    26.000000
# 75%     927.250000   131.000000   288.000000     1.000000    31.000000
# max    1236.000000   176.000000   353.000000     1.000000    45.000000
#
#             height       weight        smoke
# count  1214.000000  1200.000000  1226.000000
# mean     64.047776   128.625833     0.394780
# std       2.533409    20.971862     0.489003
# min      53.000000    87.000000     0.000000
# 25%      62.000000   114.750000     0.000000
# 50%      64.000000   125.000000     0.000000
# ...

# %%
# Cleaning the data.

# 1 delete the dupliate value.
# 2 clear the nan value.

# %%
df.isnull().sum() # finding the Null valueasthe missing values.
# this . sum function will give the sum of missing values in the perticuler column
# Out:
# case          0
# bwt           0
# gestation    13
# parity        0
# age           2
# height       22
# weight       36
# smoke        10
# dtype: int64

# %%
# Removing the missing values
df.dropna(inplace =True)

# %%
df.isnull().sum() # now all the missing (NAN ) values are droped.
# Out:
# case         0
# bwt          0
# gestation    0
# parity       0
# age          0
# height       0
# weight       0
# smoke        0
# dtype: int64

# %%
# treating the duplicate values.

df.duplicated().sum() # this will show the sum of all duplicate values here there are 0 dulpicate values.
# Out:
# np.int64(0)

# %%
# Exploratory Data Analysis (EDA).

import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['case', 'bwt', 'gestation', 'parity', 'age', 'height', 'weight',
#        'smoke'],
#       dtype='object')

# %%
df.drop(columns=['case'],inplace= True)

# %%
df.columns # this will list all columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
plt.scatter(df['gestation'], df['bwt'])
plt.xlabel('Gestation')
plt.ylabel('Birth Weight')
plt.show()

# %%
plt.scatter(df['weight'], df['bwt'])
plt.xlabel("Mother's weight")
plt.ylabel('Birth Weight')
plt.show()

# %%
df
# Out:
#       bwt  gestation  parity   age  height  weight  smoke
# 0     120      284.0       0  27.0    62.0   100.0    0.0
# 1     113      282.0       0  33.0    64.0   135.0    0.0
# 2     128      279.0       0  28.0    64.0   115.0    1.0
# 4     108      282.0       0  23.0    67.0   125.0    1.0
# 5     136      286.0       0  25.0    62.0    93.0    0.0
# ...   ...        ...     ...   ...     ...     ...    ...
# 1231  113      275.0       1  27.0    60.0   100.0    0.0
# 1232  128      265.0       0  24.0    67.0   120.0    0.0
# 1233  130      291.0       0  30.0    65.0   150.0    1.0
# 1234  125      281.0       1  21.0    65.0   110.0    0.0
# 1235  117      297.0       0  38.0    65.0   129.0    0.0
#
# [1174 rows x 7 columns]

# %%
plt.scatter(df['height'], df['bwt'])
plt.xlabel("Mother's height")
plt.ylabel('Birth Weight')
plt.show()

# %%
df.columns
# Out:
# Index(['bwt', 'gestation', 'parity', 'age', 'height', 'weight', 'smoke'], dtype='object')

# %%
plt.scatter(df['age'], df['bwt'])
plt.xlabel("Mother's age")
plt.ylabel('Birth Weight')
plt.show()

# %%
plt.scatter(df['weight'], df['bwt'])
plt.xlabel("Mother's weight")
plt.ylabel('Birth Weight')
plt.show()

# %%
df['smoke'].value_counts() # this will give the counts of the unoque values.
# Out:
# smoke
# 0.0    715
# 1.0    459
# Name: count, dtype: int64

# %%
df['smoke'].value_counts(normalize= True)*100 # this will give us the %
# Out:
# smoke
# 0.0    60.902896
# 1.0    39.097104
# Name: proportion, dtype: float64

# %%
df['parity'].unique() # this will chaeck the total number of unique values.
# Out:
# array([0, 1])

# %%
df['parity'].value_counts()
# Out:
# parity
# 0    866
# 1    308
# Name: count, dtype: int64

# %%
#Corelation of matix
df.corr()
# Out:
#                 bwt  gestation    parity       age    height    weight  \
# bwt        1.000000   0.407543 -0.043908  0.026983  0.203704  0.155923
# gestation  0.407543   1.000000  0.080916 -0.053425  0.070470  0.023655
# parity    -0.043908   0.080916  1.000000 -0.351041  0.043543 -0.096362
# age        0.026983  -0.053425 -0.351041  1.000000 -0.006453  0.147322
# height     0.203704   0.070470  0.043543 -0.006453  1.000000  0.435287
# weight     0.155923   0.023655 -0.096362  0.147322  0.435287  1.000000
# smoke     -0.246800  -0.060267 -0.009599 -0.067772  0.017507 -0.060281
#
#               smoke
# bwt       -0.246800
# gestation -0.060267
# parity    -0.009599
# age       -0.067772
# height     0.017507
# weight    -0.060281
# smoke      1.000000

# %%
df.head()
# Out:
#    bwt  gestation  parity   age  height  weight  smoke
# 0  120      284.0       0  27.0    62.0   100.0    0.0
# 1  113      282.0       0  33.0    64.0   135.0    0.0
# 2  128      279.0       0  28.0    64.0   115.0    1.0
# 4  108      282.0       0  23.0    67.0   125.0    1.0
# 5  136      286.0       0  25.0    62.0    93.0    0.0

# %%
# Splitting data in to X, Y for training and for testing the ML model.

y=df['bwt']
x = df.iloc[:,1:]
x.head()
# Out:
#    gestation  parity   age  height  weight  smoke
# 0      284.0       0  27.0    62.0   100.0    0.0
# 1      282.0       0  33.0    64.0   135.0    0.0
# 2      279.0       0  28.0    64.0   115.0    1.0
# 4      282.0       0  23.0    67.0   125.0    1.0
# 5      286.0       0  25.0    62.0    93.0    0.0

# %%
# train test split. (we use scikit learn lib in python.)
from sklearn.model_selection import train_test_split as tts

# %%
x_train, x_test, y_train, y_test = tts(x,y,test_size=0.20)

# %%
x_train.shape
# Out:
# (939, 6)

# %%
x_test.shape
# Out:
# (235, 6)

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge

# %%
lr = LinearRegression()
lasso = Lasso()
ridge = Ridge ()

# %%
# Training the model
lr.fit(x_train,y_train)
lasso.fit(x_train,y_train)
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
# Predicting.
lr_pred = lr.predict(x_test)
las_pred = lasso.predict(x_test)
rid_pred = ridge.predict(x_test)

# %%
# Model evaluation.

from sklearn.metrics import r2_score,mean_squared_error

# %%
lr_rscore= r2_score(y_test,lr_pred)
las_rscore= r2_score(y_test,las_pred)
rid_rscore= r2_score(y_test,rid_pred)

# %%
lr_mse= mean_squared_error(y_test,lr_pred)
las_mse= mean_squared_error(y_test,las_pred)
rid_mse= mean_squared_error(y_test,rid_pred)

# %%
print("\n performance of the Linear Regration Model :" )
print("R2 Score :",lr_rscore)
print("MSE Score :",lr_mse)


print("\n performance of the Lasso Regration Model :" )
print("R2 Score :",las_rscore)
print("MSE Score :",las_mse)


print("\n performance of the Ridge Regration Model :" )
print("R2 Score :",rid_rscore)
print("MSE Score :",rid_mse)
# Out:
#  performance of the Linear Regration Model :
# R2 Score : 0.2548644677325739
# MSE Score : 197.79743801212248
#
#  performance of the Lasso Regration Model :
# R2 Score : 0.2682169222447698
# MSE Score : 194.25300726185478
#
#  performance of the Ridge Regration Model :
# R2 Score : 0.25524439965622714
# MSE Score : 197.69658446553484

# %%
# Selected model is linear regression 

import pickle
with open('model/model.pkl','wb') as f: # wb is write binary ! 
    pickle.dump(lr,f)

# %%
# loading the ML 

with open ('model/model.pkl','rb') as obj: #br is read binary.
    mymodel = pickle.load(obj)

# %%
mymodel
# Out:
# LinearRegression()

# %%
x_train.head()
# Out:
#      gestation  parity   age  height  weight  smoke
# 446      288.0       1  21.0    61.0   120.0    0.0
# 378      282.0       0  24.0    67.0   128.0    1.0
# 524      285.0       0  28.0    62.0   130.0    0.0
# 5        286.0       0  25.0    62.0    93.0    0.0
# 174      279.0       0  30.0    66.0   131.0    0.0

# %%
# This is how to give input for this perticular model.

test_data = {
    'gestation':[288.0],
    'parity':[1],
    'age':[21.0],
    'height':[61.0],
    'weight':[120.0],
    'smoke':[0.0]
 }

#convert into dataframe as model is trained on this format only so it wil accept the same format

test_df = pd.DataFrame(test_data)
test_df
# Out:
#    gestation  parity   age  height  weight  smoke
# 0      288.0       1  21.0    61.0   120.0    0.0

# %%
#predicitng weight of the child.

mymodel.predict(test_df)
# Out:
# array([119.59652853])
